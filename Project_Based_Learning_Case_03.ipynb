# %% [markdown]
# ### Context

# %% [markdown]
# League of Legends adalah MOBA (Multiplayer Online Battle Arena) di mana dalam permainannya terdapat 2 tim (biru dan merah) yang saling berhadapan. Dalam satu laga permainan, ada 3 jalur yang dijadikan medan perang, hutan dan pemainnya terbagi jadi 5 peran. Tujuan permainan ini adalah menjatuhkan Nexus atau base musuh dan memenangkan permainan.

# %% [markdown]
# ### Content

# %% [markdown]
# Diketahui dataset berisi 10 menit dari pertandingan.  Game yang dimainkan berperingkat 10k (SOLO QUEUE Player) dari ELO Diamond I hingga level Master. ELO sendiri merupakan teknik pencarian pemain dengan peringkat atau tingkat keterampilan yang sejenis. Setiap permainan yang terjadi itu unik. GameId dapat membantu kamu mengambil lebih banyak atribut dari Riot API pada kolom dataset.
#
# Dari data Glossary & Variables, diketahui terdapat 19 fitur pertim (total 38) yang dikumpulkan setelah 10 menit game berlangsung. Data ini termasuk pembunuhan, kematian, emas, pengalaman dan level. Di sini kamu dibebaskan untuk melakukan beberapa rekayasa fitur untuk mendapatkan lebih banyak wawasan atau insight.
#
# Pada data diketahui juga bahwa kolom blueWins adalah nilai target atau nilai yang akan coba diprediksi, di mana jika Nilai 1 berarti tim biru menang, sedangkan jika Nilai 0 maka sebaliknya.

# %% [markdown]
# ### Glossary

# %% [markdown]
# - Warding totem: Item yang dapat diletakkan pemain di peta untuk mengungkap area terdekat. Sangat berguna untuk kontrol peta/tujuan.
# - Minions: Item yang dapat diletakkan pemain di peta untuk mengungkap area terdekat. Sangat berguna untuk kontrol peta/tujuan.
# - Jungle minions: NPC milik NO TEAM. Mereka memberi emas dan buff saat dibunuh oleh pemain.
# - Elite monsters: Monster dengan hp/damage tinggi yang memberikan bonus besar (gold/XP/stat) saat dibunuh oleh tim.
# - Dragons: Monster elit yang memberikan bonus tim saat terbunuh. Naga ke-4 yang dibunuh oleh tim memberikan bonus statistik yang sangat besar. The - - 5th dragon (Elder Dragon) menawarkan keuntungan besar bagi tim.
# - Herald: Monster elit yang memberikan bonus statistik saat dibunuh oleh pemain. Ini membantu untuk mendorong jalur dan menghancurkan struktur.
# - Towers: Struktur yang harus Anda hancurkan untuk mencapai Nexus musuh. Mereka memberi emas.
# - Level: Champion level. Mulai dari 1. Maksimal 18.

# %% [markdown]
# ### Variables

# %% [markdown]
# 1.	Gameid : ID RIOT unik dari game. Dapat digunakan dengan Riot Games API.
# 2.	Bluewins: Kolom target. 1 jika tim biru menang, 0 sebaliknya.
# 3.	blueWardsPlaced Jumlah totem penangkal yang ditempatkan oleh tim biru di peta
# 4.	blueWardsDestroyed : Jumlah totem penangkal musuh yang telah dihancurkan oleh tim biru
# 5.	blueFirstBlood : Pembunuhan pertama dari permainan. 1 jika tim biru melakukan pembunuhan pertama, 0 sebaliknya
# 6.	blueKills : Jumlah musuh yang dibunuh oleh tim biru
# 7.	blueDeaths : Jumlah kematian (tim biru)
# 8.	blueAssists : Jumlah assist kill (tim biru)
# 9.	blueEliteMonsters : Jumlah monster elit yang dibunuh oleh tim biru (Dragons and Heralds)
# 10.	blueDragons : Jumlah naga yang dibunuh oleh tim biru
# 11.	blueHeralds :  Jumlah tentara yang dibunuh oleh tim biru
# 12.	blueTowersDestroyed : Jumlah bangunan yang dihancurkan oleh tim biru (menara...)
# 13.	blueTotalGold : Tim biru total emas
# 14.	blueAvgLevel : Tingkat juara rata-rata tim biru
# 15.	blueTotalExperience : Pengalaman total tim biru
# 16.	blueTotalMinionsKilled : Total minion tim biru terbunuh (CS)
# 17.	blueTotalJungleMinionsKilled : Total monster hutan tim biru terbunuh
# 18.	blueGoldDiff : Perbedaan emas tim biru dibandingkan dengan tim musuh
# 19.	blueExperienceDiff : Tim biru mengalami perbedaan dibandingkan dengan tim musuh
# 20.	blueCSPerMin : CS tim biru (antek) per menit
# 21.	blueGoldPerMin : Emas tim biru per menit
# 22.	redWardsPlaced : Jumlah totem penangkal yang ditempatkan oleh tim merah di peta
# 23.	redWardsDestroyed : Jumlah totem penangkal musuh yang telah dihancurkan oleh tim merah
# 24.	redFirstBlood : Pembunuhan pertama dari permainan. 1 jika tim merah melakukan pembunuhan pertama, 0 sebaliknya
# 25.	redKills : Jumlah musuh yang dibunuh oleh tim merah
# 26.	redDeaths : Jumlah kematian (tim merah)
# 27.	redAssists: Jumlah assist kill (tim merah)
# 28.	redEliteMonsters : Jumlah monster elit yang dibunuh oleh tim merah (Dragons and Heralds)
# 29.	redDragons : Jumlah naga yang dibunuh oleh tim merah
# 30.	redHeralds: Jumlah bentara yang dibunuh oleh tim merah
# 31.	redTowersDestroyed : Jumlah bangunan yang dihancurkan oleh tim merah (menara)
# 32.	redTotalGold: Tim merah total emas
# 33.	redAvgLevel: Tingkat juara rata-rata tim merah
# 34.	redTotalExperience: Pengalaman total tim merah
# 35.	redTotalMinionsKilled : Total minion tim merah tewas (CS)
# 36.	redTotalJungleMinionsKilled : Total monster hutan tim merah terbunuh
# 37.	redGoldDiff : Perbedaan emas tim merah dibandingkan dengan tim musuh
# 38.	redExperienceDiff : Tim merah mengalami perbedaan dibandingkan dengan tim musuh
# 39.	redCSPerMin : CS tim merah (antek) per menit
# 40.	redGoldPerMin : Emas tim merah per menit

# %% [markdown]
# ## 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Data
data = pd.read_csv ('high_diamond_ranked_10min.csv', index_col=0)
data
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4519157822         0               28                   2               1
# 4523371949         0               12                   1               0
# 4521474530         0               15                   0               0
# 4524384067         0               43                   1               0
# 4436033771         0               75                   4               0
# ...              ...              ...                 ...             ...
# 4527873286         1               17                   2               1
# 4527797466         1               54                   0               0
# 4527713716         0               23                   1               0
# 4527628313         0               14                   4               1
# 4523772935         1               18                   0               1
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# ...

# %%
# Checking the shape of the data
data.shape
# Out:
# (9879, 39)

# %% [markdown]
# ## 2. Basic EDA & Data Preprocessing

# %%
# Checking null values
data.isnull().sum()
# Out:
# blueWins                        0
# blueWardsPlaced                 0
# blueWardsDestroyed              0
# blueFirstBlood                  0
# blueKills                       0
# blueDeaths                      0
# blueAssists                     0
# blueEliteMonsters               0
# blueDragons                     0
# blueHeralds                     0
# blueTowersDestroyed             0
# blueTotalGold                   0
# blueAvgLevel                    0
# blueTotalExperience             0
# blueTotalMinionsKilled          0
# blueTotalJungleMinionsKilled    0
# blueGoldDiff                    0
# blueExperienceDiff              0
# blueCSPerMin                    0
# blueGoldPerMin                  0
# redWardsPlaced                  0
# redWardsDestroyed               0
# redFirstBlood                   0
# redKills                        0
# redDeaths                       0
# redAssists                      0
# redEliteMonsters                0
# ...

# %%
# checking data types of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9879 entries, 4519157822 to 4523772935
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   blueWins                      9879 non-null   int64
#  1   blueWardsPlaced               9879 non-null   int64
#  2   blueWardsDestroyed            9879 non-null   int64
#  3   blueFirstBlood                9879 non-null   int64
#  4   blueKills                     9879 non-null   int64
#  5   blueDeaths                    9879 non-null   int64
#  6   blueAssists                   9879 non-null   int64
#  7   blueEliteMonsters             9879 non-null   int64
#  8   blueDragons                   9879 non-null   int64
#  9   blueHeralds                   9879 non-null   int64
#  10  blueTowersDestroyed           9879 non-null   int64
#  11  blueTotalGold                 9879 non-null   int64
# ...

# %%
#checking for quasi constants
np.var(data)
# Out:
# blueWins                        2.499991e-01
# blueWardsPlaced                 3.246579e+02
# blueWardsDestroyed              4.730139e+00
# blueFirstBlood                  2.499769e-01
# blueKills                       9.065372e+00
# blueDeaths                      8.606415e+00
# blueAssists                     1.651865e+01
# blueEliteMonsters               3.912438e-01
# blueDragons                     2.309505e-01
# blueHeralds                     1.526401e-01
# blueTowersDestroyed             5.971025e-02
# blueTotalGold                   2.357358e+06
# blueAvgLevel                    9.310455e-02
# blueTotalExperience             1.441111e+06
# blueTotalMinionsKilled          4.777429e+02
# blueTotalJungleMinionsKilled    9.796607e+01
# blueGoldDiff                    6.018313e+06
# blueExperienceDiff              3.687449e+06
# blueCSPerMin                    4.777429e+00
# blueGoldPerMin                  2.357358e+04
# redWardsPlaced                  3.406421e+02
# ...

# %%
# Bar plot of the outcomes to see how they are distributed
# BlueWins and Tim Blue

plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='blueAssists', data=data.groupby(data['blueWins']).sum().blueAssists.reset_index(), palette='Spectral')
plt.ylabel('blueAssists')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='blueAvgLevel', data=data.groupby(data['blueWins']).sum().blueAvgLevel.reset_index(), palette='Spectral')
plt.ylabel('blueAvgLevel')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='blueCSPerMin', data=data.groupby(data['blueWins']).sum().blueCSPerMin.reset_index(), palette='Spectral')
plt.ylabel('blueCSPerMin')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='blueDeaths', data=data.groupby(data['blueWins']).sum().blueDeaths.reset_index(), palette='Spectral')
plt.ylabel('blueDeaths')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='blueDragons', data=data.groupby(data['blueWins']).sum().blueDragons.reset_index(), palette='Spectral')
plt.ylabel('blueDragons')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='blueEliteMonsters', data=data.groupby(data['blueWins']).sum().blueEliteMonsters.reset_index(), palette='Spectral')
plt.ylabel('blueEliteMonsters')
plt.xlabel('blueWins')
# Out:
# <ipython-input-7-1146451bfd60>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueAssists', data=data.groupby(data['blueWins']).sum().blueAssists.reset_index(), palette='Spectral')
# <ipython-input-7-1146451bfd60>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueAvgLevel', data=data.groupby(data['blueWins']).sum().blueAvgLevel.reset_index(), palette='Spectral')
# <ipython-input-7-1146451bfd60>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='blueExperienceDiff', data=data.groupby(data['blueWins']).sum().blueExperienceDiff.reset_index(), palette='Spectral')
plt.ylabel('blueExperienceDiff')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='blueFirstBlood', data=data.groupby(data['blueWins']).sum().blueFirstBlood.reset_index(), palette='Spectral')
plt.ylabel('blueFirstBlood')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='blueGoldDiff', data=data.groupby(data['blueWins']).sum().blueGoldDiff.reset_index(), palette='Spectral')
plt.ylabel('blueGoldDiff')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='blueGoldPerMin', data=data.groupby(data['blueWins']).sum().blueGoldPerMin.reset_index(), palette='Spectral')
plt.ylabel('blueGoldPerMin')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='blueHeralds', data=data.groupby(data['blueWins']).sum().blueHeralds.reset_index(), palette='Spectral')
plt.ylabel('blueHeralds')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='blueKills', data=data.groupby(data['blueWins']).sum().blueKills.reset_index(), palette='Spectral')
plt.ylabel('blueKills')
plt.xlabel('blueWins')
# Out:
# <ipython-input-8-13835e2661ed>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueExperienceDiff', data=data.groupby(data['blueWins']).sum().blueExperienceDiff.reset_index(), palette='Spectral')
# <ipython-input-8-13835e2661ed>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueFirstBlood', data=data.groupby(data['blueWins']).sum().blueFirstBlood.reset_index(), palette='Spectral')
# <ipython-input-8-13835e2661ed>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='blueTotalExperience', data=data.groupby(data['blueWins']).sum().blueTotalExperience.reset_index(), palette='Spectral')
plt.ylabel('blueTotalExperience')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='blueTotalGold', data=data.groupby(data['blueWins']).sum().blueTotalGold.reset_index(), palette='Spectral')
plt.ylabel('blueTotalGold')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='blueTotalJungleMinionsKilled', data=data.groupby(data['blueWins']).sum().blueTotalJungleMinionsKilled.reset_index(), palette='Spectral')
plt.ylabel('blueTotalJungleMinionsKilled')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='blueTotalMinionsKilled', data=data.groupby(data['blueWins']).sum().blueTotalMinionsKilled.reset_index(), palette='Spectral')
plt.ylabel('blueTotalMinionsKilled')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='blueTowersDestroyed', data=data.groupby(data['blueWins']).sum().blueTowersDestroyed.reset_index(), palette='Spectral')
plt.ylabel('blueTowersDestroyed')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='blueWardsDestroyed', data=data.groupby(data['blueWins']).sum().blueWardsDestroyed.reset_index(), palette='Spectral')
plt.ylabel('blueWardsDestroyed')
plt.xlabel('blueWins')
# Out:
# <ipython-input-9-6aabae83749b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueTotalExperience', data=data.groupby(data['blueWins']).sum().blueTotalExperience.reset_index(), palette='Spectral')
# <ipython-input-9-6aabae83749b>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueTotalGold', data=data.groupby(data['blueWins']).sum().blueTotalGold.reset_index(), palette='Spectral')
# <ipython-input-9-6aabae83749b>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.subplot()
sns.barplot(x='blueWins', y='blueWardsPlaced', data=data.groupby(data['blueWins']).sum().blueWardsPlaced.reset_index(), palette='Spectral')
plt.ylabel('blueWardsPlaced')
plt.xlabel('blueWins')
# Out:
# <ipython-input-10-0b09efb761b4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='blueWardsPlaced', data=data.groupby(data['blueWins']).sum().blueWardsPlaced.reset_index(), palette='Spectral')
# Text(0.5, 0, 'blueWins')

# %%
# BlueWins and Tim Red

plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='redAssists', data=data.groupby(data['blueWins']).sum().redAssists.reset_index(), palette='Spectral')
plt.ylabel('redAssists')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='redAvgLevel', data=data.groupby(data['blueWins']).sum().redAvgLevel.reset_index(), palette='Spectral')
plt.ylabel('redAvgLevel')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='redCSPerMin', data=data.groupby(data['blueWins']).sum().redCSPerMin.reset_index(), palette='Spectral')
plt.ylabel('redCSPerMin')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='redDeaths', data=data.groupby(data['blueWins']).sum().redDeaths.reset_index(), palette='Spectral')
plt.ylabel('redDeaths')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='redDragons', data=data.groupby(data['blueWins']).sum().redDragons.reset_index(), palette='Spectral')
plt.ylabel('redDragons')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='redEliteMonsters', data=data.groupby(data['blueWins']).sum().redEliteMonsters.reset_index(), palette='Spectral')
plt.ylabel('redEliteMonsters')
plt.xlabel('blueWins')
# Out:
# <ipython-input-11-8070d760c0c1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redAssists', data=data.groupby(data['blueWins']).sum().redAssists.reset_index(), palette='Spectral')
# <ipython-input-11-8070d760c0c1>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redAvgLevel', data=data.groupby(data['blueWins']).sum().redAvgLevel.reset_index(), palette='Spectral')
# <ipython-input-11-8070d760c0c1>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='redExperienceDiff', data=data.groupby(data['blueWins']).sum().redExperienceDiff.reset_index(), palette='Spectral')
plt.ylabel('redExperienceDiff')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='redFirstBlood', data=data.groupby(data['blueWins']).sum().redFirstBlood.reset_index(), palette='Spectral')
plt.ylabel('redFirstBlood')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='redGoldDiff', data=data.groupby(data['blueWins']).sum().redGoldDiff.reset_index(), palette='Spectral')
plt.ylabel('redGoldDiff')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='redGoldPerMin', data=data.groupby(data['blueWins']).sum().redGoldPerMin.reset_index(), palette='Spectral')
plt.ylabel('redeGoldPerMin')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='redHeralds', data=data.groupby(data['blueWins']).sum().redHeralds.reset_index(), palette='Spectral')
plt.ylabel('redHeralds')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='redKills', data=data.groupby(data['blueWins']).sum().redKills.reset_index(), palette='Spectral')
plt.ylabel('redKills')
plt.xlabel('blueWins')
# Out:
# <ipython-input-12-d5aae61ada08>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redExperienceDiff', data=data.groupby(data['blueWins']).sum().redExperienceDiff.reset_index(), palette='Spectral')
# <ipython-input-12-d5aae61ada08>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redFirstBlood', data=data.groupby(data['blueWins']).sum().redFirstBlood.reset_index(), palette='Spectral')
# <ipython-input-12-d5aae61ada08>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
sns.barplot(x='blueWins', y='redTotalExperience', data=data.groupby(data['blueWins']).sum().redTotalExperience.reset_index(), palette='Spectral')
plt.ylabel('redTotalExperience')
plt.xlabel('blueWins')

plt.subplot(2,3,2)
sns.barplot(x='blueWins', y='redTotalGold', data=data.groupby(data['blueWins']).sum().redTotalGold.reset_index(), palette='Spectral')
plt.ylabel('redTotalGold')
plt.xlabel('blueWins')

plt.subplot(2,3,3)
sns.barplot(x='blueWins', y='redTotalJungleMinionsKilled', data=data.groupby(data['blueWins']).sum().redTotalJungleMinionsKilled.reset_index(), palette='Spectral')
plt.ylabel('redTotalJungleMinionsKilled')
plt.xlabel('blueWins')

plt.subplot(2,3,4)
sns.barplot(x='blueWins', y='redTotalMinionsKilled', data=data.groupby(data['blueWins']).sum().redTotalMinionsKilled.reset_index(), palette='Spectral')
plt.ylabel('redTotalMinionsKilled')
plt.xlabel('blueWins')

plt.subplot(2,3,5)
sns.barplot(x='blueWins', y='redTowersDestroyed', data=data.groupby(data['blueWins']).sum().redTowersDestroyed.reset_index(), palette='Spectral')
plt.ylabel('redTowersDestroyed')
plt.xlabel('blueWins')

plt.subplot(2,3,6)
sns.barplot(x='blueWins', y='redWardsDestroyed', data=data.groupby(data['blueWins']).sum().redWardsDestroyed.reset_index(), palette='Spectral')
plt.ylabel('redWardsDestroyed')
plt.xlabel('blueWins')
# Out:
# <ipython-input-13-9f70cf0090b9>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redTotalExperience', data=data.groupby(data['blueWins']).sum().redTotalExperience.reset_index(), palette='Spectral')
# <ipython-input-13-9f70cf0090b9>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redTotalGold', data=data.groupby(data['blueWins']).sum().redTotalGold.reset_index(), palette='Spectral')
# <ipython-input-13-9f70cf0090b9>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.subplot()
sns.barplot(x='blueWins', y='redWardsPlaced', data=data.groupby(data['blueWins']).sum().redWardsPlaced.reset_index(), palette='Spectral')
plt.ylabel('redWardsPlaced')
plt.xlabel('blueWins')
# Out:
# <ipython-input-14-b4ccb392e569>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='blueWins', y='redWardsPlaced', data=data.groupby(data['blueWins']).sum().redWardsPlaced.reset_index(), palette='Spectral')
# Text(0.5, 0, 'blueWins')

# %% [markdown]
# # Outlier
#  1. Bertujuan untuk mengetahui abnomali sebuah data memiliki nilai tinggi atau rendah yang berbeda dengan nilai yang lainnya.

# %%
f, axes = plt.subplots(19, 2,figsize=(20,40))
sns.set(style="white", palette="Set3", color_codes=True)
sns.boxplot(  y="blueWardsPlaced", x= "blueWins", data=data,  orient='v', ax=axes[0,0])
sns.boxplot(  y="blueWardsDestroyed", x= "blueWins", data=data,  orient='v' , ax=axes[0,1])
sns.boxplot(  y="blueFirstBlood", x= "blueWins", data=data,  orient='v' , ax=axes[1,0])
sns.boxplot(  y="blueKills", x= "blueWins", data=data,  orient='v' ,ax=axes[1,1])
sns.boxplot(  y="blueDeaths", x= "blueWins", data=data,  orient='v' , ax=axes[2,0])
sns.boxplot(  y="blueAssists", x= "blueWins", data=data,  orient='v' , ax=axes[2,1])
sns.boxplot(  y="blueEliteMonsters", x= "blueWins", data=data,  orient='v' , ax=axes[3,0])
sns.boxplot(  y="blueDragons", x= "blueWins", data=data,  orient='v' , ax=axes[3,1])
sns.boxplot(  y="blueHeralds", x= "blueWins", data=data,  orient='v' , ax=axes[4,0])
sns.boxplot(  y="blueTowersDestroyed", x= "blueWins", data=data,  orient='v' , ax=axes[4,1])
sns.boxplot(  y="blueTotalGold", x= "blueWins", data=data,  orient='v' , ax=axes[5,0])
sns.boxplot(  y="blueAvgLevel", x= "blueWins", data=data,  orient='v' , ax=axes[5,1])
sns.boxplot(  y="blueTotalExperience", x= "blueWins", data=data,  orient='v' , ax=axes[6,0])
sns.boxplot(  y="blueTotalMinionsKilled", x= "blueWins", data=data,  orient='v' , ax=axes[6,1])
sns.boxplot(  y="blueTotalJungleMinionsKilled", x= "blueWins", data=data,  orient='v' ,ax=axes[7,0])
sns.boxplot(  y="blueGoldDiff", x= "blueWins", data=data,  orient='v' , ax=axes[7,1])
sns.boxplot(  y="blueExperienceDiff", x= "blueWins", data=data,  orient='v' , ax=axes[8,0])
sns.boxplot(  y="blueCSPerMin", x= "blueWins", data=data,  orient='v' , ax=axes[8,1])
sns.boxplot(  y="blueGoldPerMin", x= "blueWins", data=data,  orient='v' , ax=axes[9,0])
sns.boxplot(  y="redWardsPlaced", x= "blueWins", data=data,  orient='v', ax=axes[9,1])
sns.boxplot(  y="redWardsDestroyed", x= "blueWins", data=data,  orient='v' , ax=axes[10,0])
sns.boxplot(  y="redFirstBlood", x= "blueWins", data=data,  orient='v' , ax=axes[10,1])
sns.boxplot(  y="redKills", x= "blueWins", data=data,  orient='v' ,ax=axes[11,0])
sns.boxplot(  y="redDeaths", x= "blueWins", data=data,  orient='v' , ax=axes[11,1])
sns.boxplot(  y="redAssists", x= "blueWins", data=data,  orient='v' , ax=axes[12,0])
sns.boxplot(  y="redEliteMonsters", x= "blueWins", data=data,  orient='v' , ax=axes[12,1])
sns.boxplot(  y="redDragons", x= "blueWins", data=data,  orient='v' , ax=axes[13,0])
sns.boxplot(  y="redHeralds", x= "blueWins", data=data,  orient='v' , ax=axes[13,1])
sns.boxplot(  y="redTowersDestroyed", x= "blueWins", data=data,  orient='v' , ax=axes[14,0])
sns.boxplot(  y="redTotalGold", x= "blueWins", data=data,  orient='v' , ax=axes[14,1])
sns.boxplot(  y="redAvgLevel", x= "blueWins", data=data,  orient='v' , ax=axes[15,0])
sns.boxplot(  y="redTotalExperience", x= "blueWins", data=data,  orient='v' , ax=axes[15,1])
sns.boxplot(  y="redTotalMinionsKilled", x= "blueWins", data=data,  orient='v' , ax=axes[16,0])
sns.boxplot(  y="redTotalJungleMinionsKilled", x= "blueWins", data=data,  orient='v' ,ax=axes[16,1])
sns.boxplot(  y="redGoldDiff", x= "blueWins", data=data,  orient='v' , ax=axes[17,0])
sns.boxplot(  y="redExperienceDiff", x= "blueWins", data=data,  orient='v' , ax=axes[17,1])
sns.boxplot(  y="redCSPerMin", x= "blueWins", data=data,  orient='v' , ax=axes[18,0])
sns.boxplot(  y="redGoldPerMin", x= "blueWins", data=data,  orient='v' , ax=axes[18,1])
f.subplots_adjust(left=0.08, right=0.98, bottom=0.05, top=0.9,
                    hspace=0.4, wspace=0.3)
plt.tight_layout()

# %%
# Value counts data blueWins
sns.countplot(x="blueWins",data=data)
data["blueWins"].value_counts()
# Out:
# blueWins
# 0    4949
# 1    4930
# Name: count, dtype: int64

# %% [markdown]
# # Buatlah catatan dari hasil data preprocessing

# %% [markdown]
# # Data Cleaning
# 1. Agar distribusi data memiliki nilai sama pada umumnya dengan data yang lain.

# %%
data_copy = data.copy(deep = True)
data_copy[['blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood','blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters','blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold','blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled','blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff','blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed','redFirstBlood', 'redKills', 'redDeaths', 'redAssists','redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed','redTotalGold', 'redAvgLevel', 'redTotalExperience','redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff','redExperienceDiff', 'redCSPerMin', 'redGoldPerMin']] = data_copy[['blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood','blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters','blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold','blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled','blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff','blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed','redFirstBlood', 'redKills', 'redDeaths', 'redAssists','redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed','redTotalGold', 'redAvgLevel', 'redTotalExperience','redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff','redExperienceDiff', 'redCSPerMin', 'redGoldPerMin']].replace(0,np.NaN)
print('Number of zero entries in each attribute:\n')
print(data_copy.isnull().sum())
# Out:
# Number of zero entries in each attribute:
#
# blueWins                           0
# blueWardsPlaced                    0
# blueWardsDestroyed               745
# blueFirstBlood                  4892
# blueKills                         63
# blueDeaths                        72
# blueAssists                      217
# blueEliteMonsters               5156
# blueDragons                     6303
# blueHeralds                     8022
# blueTowersDestroyed             9415
# blueTotalGold                      0
# blueAvgLevel                       0
# blueTotalExperience                0
# blueTotalMinionsKilled             0
# blueTotalJungleMinionsKilled       2
# blueGoldDiff                       2
# blueExperienceDiff                 1
# blueCSPerMin                       0
# blueGoldPerMin                     0
# redWardsPlaced                     0
# redWardsDestroyed                785
# redFirstBlood                   4987
# redKills                          72
# ...

# %%
data = data.hist(figsize = (15,15))

# %%
#Impute NaN values using meadian values
print('Imputing NaN values')
data_copy['blueWardsDestroyed'].fillna(data_copy['blueWardsDestroyed'].median(), inplace = True)
data_copy['blueFirstBlood'].fillna(data_copy['blueFirstBlood'].median(), inplace = True)
data_copy['blueKills'].fillna(data_copy['blueKills'].median(), inplace = True)
data_copy['blueDeaths'].fillna(data_copy['blueDeaths'].median(), inplace = True)
data_copy['blueAssists'].fillna(data_copy['blueAssists'].median(), inplace = True)
data_copy['blueEliteMonsters'].fillna(data_copy['blueEliteMonsters'].median(), inplace = True)
data_copy['blueDragons'].fillna(data_copy['blueDragons'].median(), inplace = True)
data_copy['blueHeralds'].fillna(data_copy['blueHeralds'].median(), inplace = True)
data_copy['blueTowersDestroyed'].fillna(data_copy['blueTowersDestroyed'].median(), inplace = True)
data_copy['blueTotalJungleMinionsKilled'].fillna(data_copy['blueTotalJungleMinionsKilled'].median(), inplace = True)
data_copy['blueGoldDiff'].fillna(data_copy['blueGoldDiff'].median(), inplace = True)
data_copy['blueExperienceDiff'].fillna(data_copy['blueExperienceDiff'].median(), inplace = True)
data_copy['redWardsDestroyed'].fillna(data_copy['redWardsDestroyed'].median(), inplace = True)
data_copy['redFirstBlood'].fillna(data_copy['redFirstBlood'].median(), inplace = True)
data_copy['redKills'].fillna(data_copy['redKills'].median(), inplace = True)
data_copy['redDeaths'].fillna(data_copy['redDeaths'].median(), inplace = True)
data_copy['redAssists'].fillna(data_copy['redAssists'].median(), inplace = True)
data_copy['redEliteMonsters'].fillna(data_copy['redEliteMonsters'].median(), inplace = True)
data_copy['redDragons'].fillna(data_copy['redDragons'].median(), inplace = True)
data_copy['redHeralds'].fillna(data_copy['redHeralds'].median(), inplace = True)
data_copy['redTowersDestroyed'].fillna(data_copy['redTowersDestroyed'].median(), inplace = True)
data_copy['redGoldDiff'].fillna(data_copy['redGoldDiff'].median(), inplace = True)
data_copy['redExperienceDiff'].fillna(data_copy['redExperienceDiff'].median(), inplace = True)
print('Number of zero entries in each attribute:\n')
print(data_copy.isnull().sum())
# Out:
# Imputing NaN values
# Number of zero entries in each attribute:
#
# blueWins                        0
# blueWardsPlaced                 0
# blueWardsDestroyed              0
# blueFirstBlood                  0
# blueKills                       0
# blueDeaths                      0
# blueAssists                     0
# blueEliteMonsters               0
# blueDragons                     0
# blueHeralds                     0
# blueTowersDestroyed             0
# blueTotalGold                   0
# blueAvgLevel                    0
# blueTotalExperience             0
# blueTotalMinionsKilled          0
# blueTotalJungleMinionsKilled    0
# blueGoldDiff                    0
# blueExperienceDiff              0
# blueCSPerMin                    0
# blueGoldPerMin                  0
# redWardsPlaced                  0
# redWardsDestroyed               0
# redFirstBlood                   0
# redKills                        0
# redDeaths                       0
# ...

# %%
plt.figure(figsize=(10,10))
corr = data_copy.corr()
corr.index = data_copy.columns
sns.heatmap(corr, annot = True, cmap='RdYlGn', vmin=-1, vmax=1)
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %% [markdown]
# ## 3. Data Splitting into train and test set

# %%
from sklearn.model_selection import train_test_split

X = data['blueKills']
Y = data['redKills']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size= 0.7 , random_state=0000)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (6915,)
# (6915,)
# (2964,)
# (2964,)

# %% [markdown]
# ## 4. Feature Selection and Compare Each Model

# %% [markdown]
# Method 1: Feature Selection using different methods and checking with different models

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.dummy import DummyClassifier
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RepeatedKFold, cross_val_score,KFold, RepeatedStratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
import graphviz
import warnings
warnings.filterwarnings('ignore')

# !pip install eli5
from eli5 import explain_weights,show_weights
from yellowbrick import ROCAUC
from yellowbrick.classifier import ClassificationReport

CV_N_REPEATS=20
BINS=10
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107720 sha256=75377c92fd2aaa393e134b4646ce0a622a1c990ae4051ae4aaeb71d4f70cc0c6
#   Stored in directory: /root/.cache/pip/wheels/b8/58/ef/2cf4c306898c2338d51540e0922c8e0d6028e07007085c0004
# Successfully built eli5
# ...

# %% [markdown]
# 1. Dummy Classifier

# %%
X = (data.iloc[:,0:8])
Y = (data.iloc[:,8])
test_size = 0.20
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=test_size, random_state=7)
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of X_train: (7903, 8)
# Shape of X_test: (1976, 8)

# %%
dum=DummyClassifier(strategy='most_frequent')
dum=dum.fit(X_train,Y_train)
score=dum.score(X_test, Y_test)
print("Dummy Classifier Accuracy: %.2f%%" % (score * 100.0))
# Out:
# Dummy Classifier Accuracy: 63.26%

# %%
strategy = "most_frequent"

scores = cross_val_score(dum,X, Y,
                         cv=RepeatedKFold(n_repeats=CV_N_REPEATS),
                         scoring=None)
scores_dummy = scores.copy()

score_line = "Scores (Accuracy) mean={0:.2f} +/- {1:.2f} (1 s.d.)".format(scores.mean(),scores.std())
plt.figure(figsize=(7,7))
fig, ax = plt.subplots()
pd.Series(scores).hist(ax=ax, bins=BINS)
ax.set_title(f"RepeatedKFold ({len(scores)} folds) with DummyClassifier({strategy})\n" + score_line);
ax.set_xlabel("Score")
ax.set_ylabel("Frequency");

# %% [markdown]
# 2. K-Nearest Neighbors

# %%
knn=KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train,Y_train)
scores = cross_val_score(knn, X, Y, cv=RepeatedStratifiedKFold(n_repeats=CV_N_REPEATS))
print(f"Accuracy mean={scores.mean():0.2f} +/- {scores.std():0.2f} (1 s.d.)")
# Out:
# Accuracy mean=0.75 +/- 0.01 (1 s.d.)

# %%
strategy = "most_frequent"

scores = cross_val_score(dum,X, Y,
                         cv=RepeatedKFold(n_repeats=CV_N_REPEATS),
                         scoring=None)
scores_knn = scores.copy()

score_line = "Scores (Accuracy) mean={0:.2f} +/- {1:.2f} (1 s.d.)".format(scores.mean(),scores.std())
plt.figure(figsize=(7,7))
fig, ax = plt.subplots()
pd.Series(scores).hist(ax=ax, bins=BINS)
ax.set_title(f"RepeatedKFold ({len(scores)} folds) with KNeighborsClassifier({strategy})\n" + score_line);
ax.set_xlabel("Score")
ax.set_ylabel("Frequency");

# %% [markdown]
# 3. Decision Tree

# %%
dt=DecisionTreeClassifier
dt=DecisionTreeClassifier(random_state=1, max_depth=2)
dt=dt.fit(X_train,Y_train)
dt_scores = cross_val_score(dt, X, Y, cv=RepeatedStratifiedKFold(n_repeats=CV_N_REPEATS))
print(f"Accuracy mean={dt_scores.mean():0.2f} +/- {dt_scores.std():0.2f} (1 s.d.)")
# Out:
# Accuracy mean=0.88 +/- 0.01 (1 s.d.)

# %% [markdown]
# 5. Bagging Classifier

# %%
bag=BaggingClassifier(n_estimators=100,oob_score=True)
bag=bag.fit(X_train,Y_train)

bag_scores = cross_val_score(bag, X, Y, cv=RepeatedStratifiedKFold(n_repeats=CV_N_REPEATS))
print("Accuracy mean={0:0.2f} +/- {1:0.2f} (1 s.d.)".format(scores.mean(),scores.std()))
print("Out of bag score: {0:0.2f}".format(bag.oob_score_*100) );
# Out:
# Accuracy mean=0.64 +/- 0.01 (1 s.d.)
# Out of bag score: 86.23

# %% [markdown]
# 6. Random Forest Classifier

# %%
num_estimators=100
rf = RandomForestClassifier(n_estimators=num_estimators)
rf.fit(X_train, Y_train)
rf_score=rf.score(X_test, Y_test)
print("Accuracy of Random Forest Classifier: {0:0.2f}".format(rf_score * 100.0));
Y_pred = rf.predict(X_test)
confusion_matrix(Y_pred, Y_test)
# Out:
# Accuracy of Random Forest Classifier: 87.55
# array([[1055,   51],
#        [ 195,  675]])

# %%
feature_names=X_train.columns.values
show_weights(rf,feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5828
#
#                     &plusmn; 0.0759
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 blueEliteMonsters
#             </td>
# ...

# %% [markdown]
# # Check variance in RF prediction quality

# %%
scores = cross_val_score(rf, X, Y, cv=RepeatedStratifiedKFold(n_repeats=CV_N_REPEATS))
scores_est = scores.copy()
print(f"Scores mean={scores.mean():0.2f} +/- {scores.std():0.2f} (1 s.d.)")

score_line = f"Scores (Accuracy) mean={scores.mean():0.2f} +/- {scores.std():0.2f} (1 s.d.)"
plt.figure()
fig, ax = plt.subplots()
pd.Series(scores).hist(ax=ax, bins=BINS)
ax.set_title(f"RepeatedKFold ({len(scores)} folds) with RandomForest\n" + score_line);
ax.set_xlabel("Score")
ax.set_ylabel("Frequency");
# Out:
# Scores mean=0.87 +/- 0.01 (1 s.d.)

# %% [markdown]
# # random forest classifier VS Dummy classifier

# %%
plt.figure()
fig, ax = plt.subplots()
df_dummy_est_scores = pd.DataFrame({'dummy': scores_dummy, 'RF': scores_est})
df_dummy_est_scores.plot(kind='hist', ax=ax, bins=20)
ax.set_xlabel("Score")
ax.set_title("Dummy vs RandomForest Scores");

# %% [markdown]
# # GradientBoostingClassifier (Sklearn)

# %%
params={'n_estimators': 500,'learning_rate': 0.01,'max_depth': 4, 'loss':'deviance'}
gbm=GradientBoostingClassifier(**params)
gbm.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, loss='deviance', max_depth=4,
#                            n_estimators=500)

# %% [markdown]
# ## 1. GBM

# %%
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(gbm.staged_predict(X_test)):
    test_score[i] = gbm.loss_(Y_test, Y_pred)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('GBM Deviance w.r.t Number of Estimators')
plt.plot(np.arange(params['n_estimators']) + 1, gbm.train_score_, 'b-',label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='best')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')
# Out:
# Text(0, 0.5, 'Deviance')

# %% [markdown]
# ## 2. GBM Classifier

# %%
params={'n_estimators': 100,'learning_rate': 0.01,'max_depth': 4, 'loss':'deviance'}
gbm=GradientBoostingClassifier(**params)
gbm.fit(X_train, Y_train)

y_pred = gbm.predict(X_test)
gbm_score = accuracy_score(Y_test, Y_pred)
print("Accuracy of GBM Classifier: {0:0.2f}".format(gbm_score * 100.0));
confusion_matrix(Y_pred, Y_test)
# Out:
# Accuracy of GBM Classifier: 87.55
# array([[1055,   51],
#        [ 195,  675]])

# %% [markdown]
# ## 3. GBM Model

# %%
feature_importance = gbm.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, data.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# # XgBoost

# %%
from xgboost import XGBClassifier, plot_importance,to_graphviz

param = {'max_depth': 3, 'eta': 0.8, 'subsample':1, 'objective': 'binary:logistic'}
xgb = XGBClassifier(**param)
xgb.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.8, eval_metric=None,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
Y_pred = xgb.predict(X_test)
xgb_score = accuracy_score(Y_test, Y_pred)
print("Accuracy of XGB Classifier: {0:0.2f}".format(xgb_score * 100.0));
confusion_matrix(Y_pred, Y_test)
# Out:
# Accuracy of XGB Classifier: 87.45
# array([[1056,   54],
#        [ 194,  672]])

# %%
plt.figure()
plot_importance(xgb,title="Feature importance from XGBoost model")
plt.show()

# %% [markdown]
# # Stacking

# %%
from mlxtend.classifier import StackingCVClassifier

sclf = StackingCVClassifier(classifiers=[knn, rf, xgb, gbm],
                          meta_classifier=rf)

print('10-fold cross validation:\n')

for clf, label in zip([knn, rf, xgb, gbm, rf],
                      ['KNearest Neighbors',
                       'Random Forest',
                        'XGB','GBM',
                       'MetaClassifier']):

    sclf_scores = model_selection.cross_val_score(clf, X, Y,
                                              cv=10, scoring='accuracy')
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" % (sclf_scores.mean(), sclf_scores.std(), label))
# Out:
# 10-fold cross validation:
#
# Accuracy: 0.76 (+/- 0.01) [KNearest Neighbors]
# Accuracy: 0.87 (+/- 0.01) [Random Forest]
# Accuracy: 0.87 (+/- 0.01) [XGB]
# Accuracy: 0.88 (+/- 0.01) [GBM]
# Accuracy: 0.87 (+/- 0.01) [MetaClassifier]

# %% [markdown]
# # 5. Modelling and Evaluation
#
#   * Dalam tahap ini data akan dilakukan visualisasi data, sehingga hasil data dapat di ketahui dengan mudah

# %%
models = []
models.append(('KNN', knn))
models.append(('DT', dt))
models.append(('RF', rf))
models.append(('GBM', gbm))
models.append(('XGB', xgb))

# %%
results = []
names = []

for name, model in models:
    kfold = model_selection.StratifiedKFold(n_splits=10, random_state=0, shuffle=True)
    cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring='recall')
    results.append(cv_results)
    names.append(name)
    msg = "{}: {} ({})".format(name, cv_results.mean(), cv_results.std())
    print(msg)

results.append(np.asarray(sclf_scores))
names.append('Stacking')
# Out:
# KNN: 0.5380271661737319 (0.022525325679569545)
# DT: 1.0 (0.0)
# RF: 0.9172331502433375 (0.01968384920771061)
# GBM: 0.9994413407821229 (0.0016759776536312998)
# XGB: 0.9287036602350437 (0.018506428555868364)

# %%
visualizer = ClassificationReport(knn,classes=['Not Wins','Wins'])
visualizer.score(X_test, Y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'KNeighborsClassifier Classification Report'}>

# %%
visualizer = ClassificationReport(dt,classes=['Not Wins','Wins'])
visualizer.score(X_test, Y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'DecisionTreeClassifier Classification Report'}>

# %%
visualizer = ClassificationReport(rf,classes=['Not Wins','Wins'])
visualizer.score(X_test, Y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'RandomForestClassifier Classification Report'}>

# %%
visualizer = ClassificationReport(gbm,classes=['Not Wins','Wins'])
visualizer.score(X_test, Y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'GradientBoostingClassifier Classification Report'}>

# %%
visualizer = ClassificationReport(xgb,classes=['Not Wins','Wins'])
visualizer.score(X_test, Y_test)
visualizer.poof()
# Out:
# <Axes: title={'center': 'XGBClassifier Classification Report'}>
